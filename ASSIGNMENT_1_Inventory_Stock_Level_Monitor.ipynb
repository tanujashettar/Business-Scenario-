# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/Business-Scenario-/blob/main/ASSIGNMENT_1_Inventory_Stock_Level_Monitor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A warehouse system tracks stock after daily sales.

# %%
# Input values
opening_stock = int(input("Enter Opening Stock: "))
items_sold = int(input("Enter Items Sold: "))

# Calculate remaining stock
remaining_stock = opening_stock - items_sold

# Display remaining stock
print("Remaining Stock:", remaining_stock)

# Check reorder level
if remaining_stock < 20:
    print("Reorder Required")
else:
    print("Stock Sufficient")
# Out:
# Enter Opening Stock: 30
# Enter Items Sold: 28
# Remaining Stock: 2
# Reorder Required
