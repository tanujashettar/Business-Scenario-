# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/Business-Scenario-/blob/main/ASSIGNMENT_4_Product_Return_Eligibility_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Business Scenario
# E-commerce system checks return eligibility.

# %%
# Input values
days = int(input("Enter days since delivery: "))
condition = input("Enter product condition (Good/Damaged): ")

# Check return eligibility
if days <= 7 and condition == "Good":
    print("Return Accepted")
else:
    print("Return Rejected")
# Out:
# Enter days since delivery: 5
# Enter product condition (Good/Damaged): good
# Return Rejected
